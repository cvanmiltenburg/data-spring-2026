# %%
sales=5_300_000
expenses=2_600_000
taxes=875_000

profit=sales-expenses-taxes

print(f"In 2025, the ACME company made ${sales:,} in widget sales. It had expenses of ${expenses:,} and paid ${taxes:,} in taxes. This amounted to ${profit:,} in profit.")
# Out:
# In 2025, the ACME company made $5,300,000 in widget sales. It had expenses of $2,600,000 and paid $875,000 in taxes. This amounted to $1,825,000 in profit.

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
##write a negative number
##convert to absolute
# -11 * -1
abs (-14)
# Out:
# 14

# %%
##how long is a super long number
len(230430508235023050923904230945)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 ##how long is a super long number
# ----> 2 len(230430508235023050923904230945)
#
# TypeError: object of type 'int' has no len()

# %%
len("Cole")
# Out:
# 4

# %%
type(45)
# Out:
# int

# %%
type(3.2354234)
# Out:
# float

# %%
type("Cole")
# Out:
# str

# %%
animals = ["dog", "cat", "cow"]

# %%
print(animals)
# Out:
# ['dog', 'cat', 'cow']

# %%
type(animals)
# Out:
# list

# %%
len(animals)
# Out:
# 3

# %%
## build ancd CALL the car_1 dictionary

car_1 = {"brand": "Audi", "body": "SUV", "model": "Q4", "trim": "leather", "cost": 60_000, "on_sale": False, "vin": 2973, "type": "ev"}

car_1
# Out:
# {'brand': 'Audi',
#  'body': 'SUV',
#  'model': 'Q4',
#  'trim': 'leather',
#  'cost': 60000,
#  'on_sale': False,
#  'vin': 2973,
#  'type': 'ev'}

# %%
## build and call car_2

car_2 = { 'vin': 5930,
    'brand': 'Honda',
 'body': 'Sedan',
 'model': 'Accord',
 'trim': 'cloth',
 'cost': 40000,
 'on_sale': True,
 'type': 'gas'}

car_2
# Out:
# {'vin': 5930,
#  'brand': 'Honda',
#  'body': 'Sedan',
#  'model': 'Accord',
#  'trim': 'cloth',
#  'cost': 40000,
#  'on_sale': True,
#  'type': 'gas'}

# %%
cars_list = [car_1, car_2]

cars_list
# Out:
# [{'brand': 'Audi',
#   'body': 'SUV',
#   'model': 'Q4',
#   'trim': 'leather',
#   'cost': 60000,
#   'on_sale': False,
#   'vin': 2973,
#   'type': 'ev'},
#  {'vin': 5930,
#   'brand': 'Honda',
#   'body': 'Sedan',
#   'model': 'Accord',
#   'trim': 'cloth',
#   'cost': 40000,
#   'on_sale': True,
#   'type': 'gas'}]

# %%
## import library
import pandas as pd

# %%
## use pandas to read dataset and provide an overview

pd.read_csv("insurance.csv")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
